# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachu9/Python_libraries/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas
import numpy as np

# %%
import pandas as pd

# %%
l=[1,2,3,4,5]
n=pd.Series(l)
n
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
n[2]
# Out:
# 3

# %%
import pandas as pd

# Data and index
l = [10, 20, 30, 40]  # Data values
ind = ['A', 'B', 'C', 'D']  # Index labels

# Create the Series
n = pd.Series(l, ind)

print(n)
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64

# %%
chocolate={"DairyMilk":100, "Crispello":90}
a=pd.Series(chocolate)
a
# Out:
# DairyMilk    100
# Crispello     90
# dtype: int64

# %%
a["DairyMilk"]
# Out:
# 100

# %%
from numpy.random import randn

# %%
data=randn(2,2)
row=["A","B"]
col=["Hi","Hello"]
df=pd.DataFrame(data,row,col)
df
# Out:
#          Hi     Hello
# A -0.819329  0.477393
# B  1.847562  0.438696

# %%
df.head()
# Out:
#          Hi     Hello
# A -0.819329  0.477393
# B  1.847562  0.438696

# %%
df.tail()
# Out:
#          Hi     Hello
# A -0.819329  0.477393
# B  1.847562  0.438696

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b50977ee8ee5> in <cell line: 1>()
# ----> 1 df.loc[A]
#
# NameError: name 'A' is not defined
